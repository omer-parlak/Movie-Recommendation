# %% [markdown]
# <a href="https://www.kaggle.com/omerparlak/item-based-and-user-based-movie-recommandation?scriptVersionId=88257581" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Business Problem

# %% [markdown]
# #### Movie recommendation for random users with item-based and user-based methods.

# %%
import numpy as np
import pandas as pd
pd.pandas.set_option('display.max_columns', 10)

# %%
def create_user_movie_df():
    movie = pd.read_csv("../input/movielens-20m-dataset/movie.csv")
    rating = pd.read_csv("../input/movielens-20m-dataset/rating.csv")
    df = movie.merge(rating, how="left", on="movieId")
    comment_counts = pd.DataFrame(df["title"].value_counts())
    rare_movies = comment_counts[comment_counts["title"] <= 1500].index
    common_movies = df[~df["title"].isin(rare_movies)]
    user_movie_df = common_movies.pivot_table(index=["userId"], columns=["title"], values="rating")
    return user_movie_df


def item_based_recommender(movie_name, user_movie_df):
    movie = user_movie_df[movie_name]
    return user_movie_df.corrwith(movie).sort_values(ascending=False).head(10)

# %% [markdown]
# # Data Preprocessing

# %%
user_movie_df = create_user_movie_df()
user_movie_df.head()
# Out:
# title   'burbs, The (1989)  (500) Days of Summer (2009)  \
# userId
# 1.0                    NaN                          NaN
# 2.0                    NaN                          NaN
# 3.0                    NaN                          NaN
# 4.0                    NaN                          NaN
# 5.0                    NaN                          NaN
#
# title   *batteries not included (1987)  10 Things I Hate About You (1999)  \
# userId
# 1.0                                NaN                                NaN
# 2.0                                NaN                                NaN
# 3.0                                NaN                                NaN
# 4.0                                NaN                                NaN
# 5.0                                NaN                                NaN
#
# title   10,000 BC (2008)  ...  Zombieland (2009)  Zoolander (2001)  \
# userId                    ...
# 1.0                  NaN  ...                NaN               NaN
# 2.0                  NaN  ...                NaN               NaN
# 3.0                  NaN  ...                NaN               NaN
# 4.0                  NaN  ...                NaN               NaN
# 5.0                  NaN  ...                NaN               NaN
#
# title   eXistenZ (1999)  xXx (2002)  ¡Three Amigos! (1986)
# userId
# 1.0                 NaN         NaN                    NaN
# 2.0                 NaN         NaN                    NaN
# 3.0                 NaN         NaN                    NaN
# 4.0                 NaN         NaN                    NaN
# 5.0                 NaN         NaN                    NaN
#
# [5 rows x 2449 columns]

# %% [markdown]
# # Determining the Movies Watched by the Random User

# %%
random_user = int(pd.Series(user_movie_df.index).sample(1, random_state=17).values)
random_user
# Out:
# 42504

# %%
random_user_df = user_movie_df[user_movie_df.index == random_user]
random_user_df
# Out:
# title    'burbs, The (1989)  (500) Days of Summer (2009)  \
# userId
# 42504.0                 NaN                          4.0
#
# title    *batteries not included (1987)  10 Things I Hate About You (1999)  \
# userId
# 42504.0                             NaN                                NaN
#
# title    10,000 BC (2008)  ...  Zombieland (2009)  Zoolander (2001)  \
# userId                     ...
# 42504.0               NaN  ...                4.0               NaN
#
# title    eXistenZ (1999)  xXx (2002)  ¡Three Amigos! (1986)
# userId
# 42504.0              NaN         NaN                    4.0
#
# [1 rows x 2449 columns]

# %%
movies_watched = random_user_df.columns[random_user_df.notna().any()].tolist()
movies_watched
# Out:
# ['(500) Days of Summer (2009)',
#  '127 Hours (2010)',
#  '2 Fast 2 Furious (Fast and the Furious 2, The) (2003)',
#  '20,000 Leagues Under the Sea (1954)',
#  '2001: A Space Odyssey (1968)',
#  '21 (2008)',
#  '40-Year-Old Virgin, The (2005)',
#  '8 Mile (2002)',
#  'Amazing Spider-Man, The (2012)',
#  'American Beauty (1999)',
#  'American History X (1998)',
#  'American Pie (1999)',
#  'Anchorman: The Legend of Ron Burgundy (2004)',
#  'Apollo 13 (1995)',
#  'Avatar (2009)',
#  'Back to the Future (1985)',
#  'Band of Brothers (2001)',
#  'Bank Job, The (2008)',
#  'Batman Begins (2005)',
#  'Battlestar Galactica (2003)',
#  'Big (1988)',
#  'Blade Runner (1982)',
#  'Blues Brothers, The (1980)',
#  'Bourne Identity, The (2002)',
#  'Bourne Supremacy, The (2004)',
#  'Bourne Ultimatum, The (2007)',
#  'Bowling for Columbine (2002)',
#  'Braveheart (1995)',
#  'Bruce Almighty (2003)',
#  'Cabin in the Woods, The (2012)',
#  'Casino Royale (2006)',
#  "Charlie Wilson's War (2007)",
#  'Cloud Atlas (2012)',
#  'Con Air (1997)',
#  'Contact (1997)',
#  'Corporation, The (2003)',
#  'Cube (1997)',
#  'Curious Case of Benjamin Button, The (2008)',
#  'Dances with Wolves (1990)',
#  'Dark Knight, The (2008)',
#  'Dish, The (2001)',
#  'District 9 (2009)',
#  'Dodgeball: A True Underdog Story (2004)',
#  'Equilibrium (2002)',
#  'Event Horizon (1997)',
#  'Evolution (2001)',
#  'Fahrenheit 9/11 (2004)',
#  'Fifth Element, The (1997)',
#  'Fight Club (1999)',
#  'Flight of the Navigator (1986)',
#  'Forgetting Sarah Marshall (2008)',
#  'Forrest Gump (1994)',
#  'Fugitive, The (1993)',
#  'Galaxy Quest (1999)',
#  'Gattaca (1997)',
#  'Gladiator (2000)',
#  'Godfather, The (1972)',
#  'Good Will Hunting (1997)',
#  'Great Escape, The (1963)',
#  'Green Mile, The (1999)',
#  'Groundhog Day (1993)',
#  'Hangover, The (2009)',
#  'Harry Potter and the Goblet of Fire (2005)',
#  'Harry Potter and the Half-Blood Prince (2009)',
#  'Hotel Rwanda (2004)',
#  'Hunger Games, The (2012)',
#  'I Am Legend (2007)',
#  'I Love You, Man (2009)',
#  'Inception (2010)',
#  'Independence Day (a.k.a. ID4) (1996)',
#  'Intouchables (2011)',
#  'Iron Man (2008)',
#  'Iron Man 2 (2010)',
#  'Jarhead (2005)',
#  'Juno (2007)',
#  'Jurassic Park (1993)',
#  'Kick-Ass (2010)',
#  "King's Speech, The (2010)",
#  'Knocked Up (2007)',
#  'Last Samurai, The (2003)',
#  'Limitless (2011)',
#  'Lion King, The (1994)',
#  'Looper (2012)',
#  'Lord of the Rings: The Fellowship of the Ring, The (2001)',
#  'Lord of the Rings: The Return of the King, The (2003)',
#  'Lord of the Rings: The Two Towers, The (2002)',
#  'Man from Earth, The (2007)',
#  'Matrix Reloaded, The (2003)',
#  'Matrix, The (1999)',
#  'Men in Black (a.k.a. MIB) (1997)',
#  'Mighty Ducks, The (1992)',
#  'Minority Report (2002)',
#  'Mission to Mars (2000)',
#  'Mission: Impossible - Ghost Protocol (2011)',
#  'Moon (2009)',
#  'Munich (2005)',
#  'Naked Gun: From the Files of Police Squad!, The (1988)',
#  "Ocean's Eleven (2001)",
#  'Office Space (1999)',
#  'Pineapple Express (2008)',
#  'Pitch Black (2000)',
#  'Pulp Fiction (1994)',
#  'Ratatouille (2007)',
#  'Red (2010)',
#  'Rise of the Planet of the Apes (2011)',
#  'Road Trip (2000)',
#  'Robin Hood (1973)',
#  'Roger & Me (1989)',
#  'Saving Private Ryan (1998)',
#  'Saw (2004)',
#  "Schindler's List (1993)",
#  'Scream 3 (2000)',
#  'Serenity (2005)',
#  'Seven (a.k.a. Se7en) (1995)',
#  'Shawshank Redemption, The (1994)',
#  'Sherlock Holmes: A Game of Shadows (2011)',
#  'Shrek (2001)',
#  'Shrek 2 (2004)',
#  'Shutter Island (2010)',
#  'Sixth Sense, The (1999)',
#  'Social Network, The (2010)',
#  'Sound of Music, The (1965)',
#  'Source Code (2011)',
#  'Sphere (1998)',
#  'Spy Hard (1996)',
#  'Star Trek (2009)',
#  'Star Trek II: The Wrath of Khan (1982)',
#  'Star Trek IV: The Voyage Home (1986)',
#  'Star Trek V: The Final Frontier (1989)',
#  'Star Trek: First Contact (1996)',
#  'Star Trek: Generations (1994)',
#  'Star Trek: Insurrection (1998)',
#  'Star Trek: Nemesis (2002)',
#  'Star Wars: Episode I - The Phantom Menace (1999)',
#  'Star Wars: Episode IV - A New Hope (1977)',
#  'Star Wars: Episode V - The Empire Strikes Back (1980)',
#  'Star Wars: Episode VI - Return of the Jedi (1983)',
#  'Stargate (1994)',
#  'Stranger than Fiction (2006)',
#  'Sunshine (2007)',
#  'Superbad (2007)',
#  'Terminator 2: Judgment Day (1991)',
#  'Terminator 3: Rise of the Machines (2003)',
#  'Terminator, The (1984)',
#  'The Butterfly Effect (2004)',
#  'Three Men and a Baby (1987)',
#  'Timecop (1994)',
#  'Titanic (1997)',
#  'Total Recall (1990)',
#  'Town, The (2010)',
#  'Toy Story 3 (2010)',
#  'Trading Places (1983)',
#  'Twelve Monkeys (a.k.a. 12 Monkeys) (1995)',
#  'U-571 (2000)',
#  'United 93 (2006)',
#  'Usual Suspects, The (1995)',
#  'V for Vendetta (2006)',
#  'Waterboy, The (1998)',
#  'Wedding Crashers (2005)',
#  'Wedding Singer, The (1998)',
#  'X-Men: First Class (2011)',
#  "You've Got Mail (1998)",
#  'Zack and Miri Make a Porno (2008)',
#  'Zombieland (2009)',
#  '¡Three Amigos! (1986)']

# %%
len(movies_watched)
# Out:
# 165

# %% [markdown]
# # Accessing Data and Ids of Other Users Watching the Same Movies

# %%
movies_watched_df = user_movie_df[movies_watched]
movies_watched_df
# Out:
# title     (500) Days of Summer (2009)  127 Hours (2010)  \
# userId
# 1.0                               NaN               NaN
# 2.0                               NaN               NaN
# 3.0                               NaN               NaN
# 4.0                               NaN               NaN
# 5.0                               NaN               NaN
# ...                               ...               ...
# 138489.0                          NaN               NaN
# 138490.0                          NaN               NaN
# 138491.0                          NaN               NaN
# 138492.0                          NaN               NaN
# 138493.0                          NaN               NaN
#
# title     2 Fast 2 Furious (Fast and the Furious 2, The) (2003)  \
# userId
# 1.0                                                     NaN
# 2.0                                                     NaN
# 3.0                                                     NaN
# 4.0                                                     NaN
# 5.0                                                     NaN
# ...                                                     ...
# 138489.0                                                NaN
# 138490.0                                                NaN
# 138491.0                                                NaN
# 138492.0                                                NaN
# 138493.0                                                NaN
#
# title     20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# userId
# 1.0                                       NaN                           3.5
# 2.0                                       NaN                           5.0
# 3.0                                       NaN                           5.0
# 4.0                                       NaN                           NaN
# 5.0                                       NaN                           NaN
# ...                                       ...                           ...
# 138489.0                                  NaN                           NaN
# 138490.0                                  NaN                           NaN
# 138491.0                                  NaN                           NaN
# 138492.0                                  NaN                           NaN
# 138493.0                                  NaN                           NaN
#
# title     ...  X-Men: First Class (2011)  You've Got Mail (1998)  \
# userId    ...
# 1.0       ...                        NaN                     NaN
# 2.0       ...                        NaN                     NaN
# 3.0       ...                        NaN                     NaN
# 4.0       ...                        NaN                     NaN
# 5.0       ...                        NaN                     NaN
# ...       ...                        ...                     ...
# 138489.0  ...                        NaN                     NaN
# 138490.0  ...                        NaN                     NaN
# 138491.0  ...                        NaN                     NaN
# 138492.0  ...                        NaN                     NaN
# 138493.0  ...                        NaN                     5.0
#
# title     Zack and Miri Make a Porno (2008)  Zombieland (2009)  \
# userId
# 1.0                                     NaN                NaN
# 2.0                                     NaN                NaN
# 3.0                                     NaN                NaN
# 4.0                                     NaN                NaN
# 5.0                                     NaN                NaN
# ...                                     ...                ...
# 138489.0                                NaN                NaN
# 138490.0                                NaN                NaN
# 138491.0                                NaN                NaN
# 138492.0                                NaN                NaN
# 138493.0                                NaN                NaN
#
# title     ¡Three Amigos! (1986)
# userId
# 1.0                         NaN
# 2.0                         NaN
# 3.0                         NaN
# 4.0                         NaN
# 5.0                         NaN
# ...                         ...
# 138489.0                    NaN
# 138490.0                    NaN
# 138491.0                    NaN
# 138492.0                    NaN
# 138493.0                    NaN
#
# [138493 rows x 165 columns]

# %%
# Count of same movies
user_movie_count = movies_watched_df.T.notnull().sum()
user_movie_count
# Out:
# userId
# 1.0         21
# 2.0         13
# 3.0         34
# 4.0          5
# 5.0         14
#             ..
# 138489.0     7
# 138490.0     8
# 138491.0     3
# 138492.0    10
# 138493.0    39
# Length: 138493, dtype: int64

# %%
user_movie_count = user_movie_count.reset_index()
user_movie_count.columns = ["userId", "movie_count"]
user_movie_count
# Out:
#           userId  movie_count
# 0            1.0           21
# 1            2.0           13
# 2            3.0           34
# 3            4.0            5
# 4            5.0           14
# ...          ...          ...
# 138488  138489.0            7
# 138489  138490.0            8
# 138490  138491.0            3
# 138491  138492.0           10
# 138492  138493.0           39
#
# [138493 rows x 2 columns]

# %%
# Users who watched 60% of movies watched by random_user

perc = len(movies_watched) * 60 / 100
users_same_movies = user_movie_count[user_movie_count["movie_count"] > perc]["userId"]
users_same_movies
# Out:
# 571          572.0
# 585          586.0
# 636          637.0
# 767          768.0
# 981          982.0
#             ...
# 138185    138186.0
# 138207    138208.0
# 138253    138254.0
# 138300    138301.0
# 138436    138437.0
# Name: userId, Length: 1106, dtype: float64

# %% [markdown]
# # Identifying Users Most Similar to the User to be Recommended

# %%
final_df = pd.concat([movies_watched_df[movies_watched_df.index.isin(users_same_movies.index)], random_user_df[movies_watched]])
final_df.head()
# Out:
# title   (500) Days of Summer (2009)  127 Hours (2010)  \
# userId
# 571.0                           NaN               NaN
# 585.0                           NaN               NaN
# 636.0                           NaN               NaN
# 767.0                           NaN               NaN
# 981.0                           NaN               NaN
#
# title   2 Fast 2 Furious (Fast and the Furious 2, The) (2003)  \
# userId
# 571.0                                                 NaN
# 585.0                                                 NaN
# 636.0                                                 NaN
# 767.0                                                 NaN
# 981.0                                                 NaN
#
# title   20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# userId
# 571.0                                   NaN                           NaN
# 585.0                                   NaN                           NaN
# 636.0                                   NaN                           NaN
# 767.0                                   NaN                           NaN
# 981.0                                   NaN                           NaN
#
# title   ...  X-Men: First Class (2011)  You've Got Mail (1998)  \
# userId  ...
# 571.0   ...                        NaN                     NaN
# 585.0   ...                        NaN                     NaN
# 636.0   ...                        NaN                     NaN
# 767.0   ...                        NaN                     NaN
# 981.0   ...                        NaN                     NaN
#
# title   Zack and Miri Make a Porno (2008)  Zombieland (2009)  \
# userId
# 571.0                                 NaN                NaN
# 585.0                                 NaN                NaN
# 636.0                                 NaN                NaN
# 767.0                                 NaN                NaN
# 981.0                                 NaN                NaN
#
# title   ¡Three Amigos! (1986)
# userId
# 571.0                     NaN
# 585.0                     NaN
# 636.0                     NaN
# 767.0                     NaN
# 981.0                     NaN
#
# [5 rows x 165 columns]

# %%
corr_df = final_df.T.corr().unstack().sort_values().drop_duplicates()
corr_df = pd.DataFrame(corr_df, columns=["corr"])
corr_df.index.names = ['user_id_1', 'user_id_2']
corr_df = corr_df.reset_index()
corr_df.head()
# Out:
#    user_id_1  user_id_2  corr
# 0    56166.0     8151.0  -1.0
# 1    50359.0    83967.0  -1.0
# 2    33574.0    27052.0  -1.0
# 3    90077.0    82416.0  -1.0
# 4    16675.0    93668.0  -1.0

# %%
# Users with a correlation of over 65%
top_users = corr_df[(corr_df["user_id_1"] == random_user) & (corr_df["corr"] >= 0.65)][["user_id_2", "corr"]].reset_index(drop=True)
top_users = top_users.sort_values(by='corr', ascending=False)
top_users.rename(columns={"user_id_2": "userId"}, inplace=True)
top_users
# Out:
#      userId      corr
# 9   56960.0  0.906329
# 8   26834.0  0.873793
# 7   11247.0  0.855209
# 6  101154.0  0.851122
# 5   44383.0  0.806144
# 4  119366.0  0.762672
# 3   29672.0  0.753399
# 2  128257.0  0.723339
# 1   80667.0  0.721995
# 0   72516.0  0.708241

# %% [markdown]
# # Calculating Weighted Average Recommendation Score and Keeping Top 5 Movies

# %%
rating = pd.read_csv("../input/movielens-20m-dataset/rating.csv")

# %%
top_users_ratings = top_users.merge(rating[["userId", "movieId", "rating"]], how='inner')
top_users_ratings.head()
# Out:
#     userId      corr  movieId  rating
# 0  56960.0  0.906329      111     3.5
# 1  56960.0  0.906329      260     4.5
# 2  56960.0  0.906329      296     4.5
# 3  56960.0  0.906329      527     5.0
# 4  56960.0  0.906329      541     3.5

# %%
top_users_ratings['weighted_rating'] = top_users_ratings['corr'] * top_users_ratings['rating']
top_users_ratings.groupby('movieId').agg({"weighted_rating": "mean"})
# Out:
#          weighted_rating
# movieId
# 1               3.609974
# 2               3.013596
# 3               3.609974
# 6               2.887979
# 7               2.887979
# ...                  ...
# 61024           3.013596
# 68319           2.260197
# 72998           3.766995
# 77800           2.821502
# 79132           4.531646
#
# [484 rows x 1 columns]

# %%
recommendation_df = top_users_ratings.groupby('movieId').agg({"weighted_rating": "mean"})
recommendation_df = recommendation_df.reset_index()

# %%
# Let's get weighted_rating greater than 4
movies_to_be_recommend = recommendation_df[recommendation_df["weighted_rating"] > 4].sort_values("weighted_rating",ascending=False)
movies_to_be_recommend
# Out:
#      movieId  weighted_rating
# 483    79132         4.531646
# 163     1201         4.531646
# 454     8368         4.368963
# 373     4896         4.368963
# 356     4262         4.368963
# 162     1199         4.255612
# 430     6377         4.255612
# 398     5893         4.255612
# 384     5325         4.255612
# 44       223         4.255612
# 299     2692         4.255612
# 281     2342         4.255612
# 262     2105         4.255612
# 180     1248         4.255612
# 355     4226         4.255612
# 450     7153         4.149320
# 181     1250         4.078481
# 168     1209         4.078481

# %%
movie = pd.read_csv("../input/movielens-20m-dataset/movie.csv")

# %%
movies_to_be_recommend_final = movies_to_be_recommend.merge(movie[["movieId", "title"]])
movies_to_be_recommend_final
# Out:
#     movieId  weighted_rating  \
# 0     79132         4.531646
# 1      1201         4.531646
# 2      8368         4.368963
# 3      4896         4.368963
# 4      4262         4.368963
# 5      1199         4.255612
# 6      6377         4.255612
# 7      5893         4.255612
# 8      5325         4.255612
# 9       223         4.255612
# 10     2692         4.255612
# 11     2342         4.255612
# 12     2105         4.255612
# 13     1248         4.255612
# 14     4226         4.255612
# 15     7153         4.149320
# 16     1250         4.078481
# 17     1209         4.078481
#
#                                                 title
# 0                                    Inception (2010)
# 1   Good, the Bad and the Ugly, The (Buono, il bru...
# 2     Harry Potter and the Prisoner of Azkaban (2004)
# 3   Harry Potter and the Sorcerer's Stone (a.k.a. ...
# 4                                     Scarface (1983)
# 5                                       Brazil (1985)
# 6                                 Finding Nemo (2003)
# 7                          Last Seduction, The (1994)
# 8                           Dogtown and Z-Boyz (2001)
# 9                                       Clerks (1994)
# 10                   Run Lola Run (Lola rennt) (1998)
# 11                              Hard Core Logo (1996)
# 12                                        Tron (1982)
# 13                               Touch of Evil (1958)
# 14                                     Memento (2000)
# 15  Lord of the Rings: The Return of the King, The...
# 16               Bridge on the River Kwai, The (1957)
# 17  Once Upon a Time in the West (C'era una volta ...

# %%
# Extracting movies watched by random_user from recommended movies 
# (dropped Inception(2010))
movies_to_be_recommend_final = movies_to_be_recommend_final[~movies_to_be_recommend_final["title"].isin(movies_watched)]
movies_to_be_recommend_final.head()
# Out:
#    movieId  weighted_rating                                              title
# 1     1201         4.531646  Good, the Bad and the Ugly, The (Buono, il bru...
# 2     8368         4.368963    Harry Potter and the Prisoner of Azkaban (2004)
# 3     4896         4.368963  Harry Potter and the Sorcerer's Stone (a.k.a. ...
# 4     4262         4.368963                                    Scarface (1983)
# 5     1199         4.255612                                      Brazil (1985)

# %% [markdown]
# # Item Based Recommendation

# %%
movie = pd.read_csv("../input/movielens-20m-dataset/movie.csv")
rating = pd.read_csv("../input/movielens-20m-dataset/rating.csv")

# %%
df = movie.merge(rating, how="left", on="movieId")
comment_counts = pd.DataFrame(df["title"].value_counts())
rare_movies = comment_counts[comment_counts["title"] <= 1500].index
common_movies = df[~df["title"].isin(rare_movies)]
common_movies.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating            timestamp
# 0     3.0     4.0  1999-12-11 13:36:47
# 1     6.0     5.0  1997-03-13 17:50:52
# 2     8.0     4.0  1996-06-05 13:37:51
# 3    10.0     4.0  1999-11-25 02:44:47
# 4    11.0     4.5  2009-01-02 01:13:41

# %%
common_movies.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating            timestamp
# 0     3.0     4.0  1999-12-11 13:36:47
# 1     6.0     5.0  1997-03-13 17:50:52
# 2     8.0     4.0  1996-06-05 13:37:51
# 3    10.0     4.0  1999-11-25 02:44:47
# 4    11.0     4.5  2009-01-02 01:13:41

# %%
common_movies[(common_movies["userId"] == random_user) & (common_movies["rating"] == 5.0)]
# Out:
#           movieId                                              title  \
# 2091001       316                                    Stargate (1994)
# 2224471       329                      Star Trek: Generations (1994)
# 2478208       356                                Forrest Gump (1994)
# 3495195       527                            Schindler's List (1993)
# 3886146       589                  Terminator 2: Judgment Day (1991)
# 6416125      1210  Star Wars: Episode VI - Return of the Jedi (1983)
# 7009445      1265                               Groundhog Day (1993)
# 7634649      1376               Star Trek IV: The Voyage Home (1986)
# 8458683      1653                                     Gattaca (1997)
# 11032110     2571                                 Matrix, The (1999)
# 12699390     3175                                Galaxy Quest (1999)
# 17420271     8641       Anchorman: The Legend of Ron Burgundy (2004)
# 18778110    54503                                    Superbad (2007)
# 18972961    58559                            Dark Knight, The (2008)
# 19420636    72998                                      Avatar (2009)
# 19533045    79132                                   Inception (2010)
#
#                                                    genres   userId  rating  \
# 2091001                           Action|Adventure|Sci-Fi  42504.0     5.0
# 2224471                            Adventure|Drama|Sci-Fi  42504.0     5.0
# 2478208                          Comedy|Drama|Romance|War  42504.0     5.0
# 3495195                                         Drama|War  42504.0     5.0
# 3886146                                     Action|Sci-Fi  42504.0     5.0
# 6416125                           Action|Adventure|Sci-Fi  42504.0     5.0
# 7009445                            Comedy|Fantasy|Romance  42504.0     5.0
# 7634649                           Adventure|Comedy|Sci-Fi  42504.0     5.0
# 8458683                             Drama|Sci-Fi|Thriller  42504.0     5.0
# 11032110                           Action|Sci-Fi|Thriller  42504.0     5.0
# 12699390                          Adventure|Comedy|Sci-Fi  42504.0     5.0
# 17420271                                           Comedy  42504.0     5.0
# 18778110                                           Comedy  42504.0     5.0
# 18972961                          Action|Crime|Drama|IMAX  42504.0     5.0
# 19420636                     Action|Adventure|Sci-Fi|IMAX  42504.0     5.0
# 19533045  Action|Crime|Drama|Mystery|Sci-Fi|Thriller|IMAX  42504.0     5.0
#
#                     timestamp
# 2091001   2012-07-26 21:47:33
# 2224471   2012-07-26 21:55:34
# 2478208   2012-07-26 22:44:08
# 3495195   2011-03-07 09:53:26
# 3886146   2011-04-09 14:05:35
# 6416125   2011-03-07 09:57:25
# 7009445   2011-03-07 10:07:13
# 7634649   2012-07-26 22:15:32
# 8458683   2011-04-09 14:08:09
# 11032110  2012-08-05 14:23:46
# 12699390  2011-05-28 16:13:56
# 17420271  2012-08-05 14:23:07
# 18778110  2012-07-26 22:45:51
# 18972961  2012-07-16 23:37:40
# 19420636  2011-03-07 09:59:44
# 19533045  2011-03-07 09:52:40

# %%
# Getting the last movie id that random_user gave 5 points
movie_id = common_movies[(common_movies["userId"] == random_user) & (common_movies["rating"] == 5.0)] \
.sort_values(by="timestamp", ascending=False)["movieId"][0:1].values[0]
movie_id
# Out:
# 2571

# %%
movie_name = movie[movie["movieId"] == movie_id]["title"].values[0]
movie_name
# Out:
# 'Matrix, The (1999)'

# %%
# movies_from_item_based[0:1].index = ['Matrix, The (1999)'] 
movies_from_item_based = item_based_recommender(common_movies[common_movies["movieId"] == movie_id]["title"].values[0], user_movie_df)
movies_from_item_based[1:6].index
# Out:
# Index(['Matrix Reloaded, The (2003)', 'Matrix Revolutions, The (2003)',
#        'Animatrix, The (2003)', 'Blade (1998)',
#        'Terminator 2: Judgment Day (1991)'],
#       dtype='object', name='title')
